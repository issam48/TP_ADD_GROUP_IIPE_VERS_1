# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
get_ipython().run_line_magic('matplotlib','inline')

# %%
cov_death=pd.read_csv('full_data.csv',encoding="unicode_escape")
cov_death
# Out:
#               date     location  new_cases  new_deaths  total_cases  \
# 0       2020-01-03  Afghanistan        0.0         0.0          NaN
# 1       2020-01-04  Afghanistan        0.0         0.0          NaN
# 2       2020-01-05  Afghanistan        0.0         0.0          NaN
# 3       2020-01-06  Afghanistan        0.0         0.0          NaN
# 4       2020-01-07  Afghanistan        0.0         0.0          NaN
# ...            ...          ...        ...         ...          ...
# 344395  2023-10-29     Zimbabwe        0.0         0.0     265821.0
# 344396  2023-10-30     Zimbabwe        0.0         0.0     265821.0
# 344397  2023-10-31     Zimbabwe        0.0         0.0     265821.0
# 344398  2023-11-01     Zimbabwe        0.0         0.0     265821.0
# 344399  2023-11-02     Zimbabwe        0.0         0.0     265821.0
#
#         total_deaths  weekly_cases  weekly_deaths  biweekly_cases  \
# 0                NaN           NaN            NaN             NaN
# 1                NaN           NaN            NaN             NaN
# 2                NaN           NaN            NaN             NaN
# 3                NaN           NaN            NaN             NaN
# 4                NaN           NaN            NaN             NaN
# ...              ...           ...            ...             ...
# 344395        5720.0           0.0            0.0            13.0
# 344396        5720.0           0.0            0.0            13.0
# 344397        5720.0           0.0            0.0             0.0
# 344398        5720.0           0.0            0.0             0.0
# 344399        5720.0           0.0            0.0             0.0
#
#         biweekly_deaths
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 344395              1.0
# 344396              1.0
# 344397              0.0
# 344398              0.0
# 344399              0.0
#
# [344400 rows x 10 columns]

# %%
cov_death.shape
# Out:
# (344400, 10)

# %%
cov_death.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344400 entries, 0 to 344399
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   date             344400 non-null  object
#  1   location         344400 non-null  object
#  2   new_cases        344151 non-null  float64
#  3   new_deaths       344196 non-null  float64
#  4   total_cases      315748 non-null  float64
#  5   total_deaths     294071 non-null  float64
#  6   weekly_cases     342892 non-null  float64
#  7   weekly_deaths    342966 non-null  float64
#  8   biweekly_cases   341116 non-null  float64
#  9   biweekly_deaths  341242 non-null  float64
# dtypes: float64(8), object(2)
# memory usage: 26.3+ MB

# %%
cov_death['date'] = pd.to_datetime(cov_death['date'])


cov_death['year'] = cov_death['date'].dt.year
cov_death['month'] = cov_death['date'].dt.month
cov_death['day'] = cov_death['date'].dt.day

# %%
cov_death.isnull().sum()
# Out:
# date                   0
# location               0
# new_cases            249
# new_deaths           204
# total_cases        28652
# total_deaths       50329
# weekly_cases        1508
# weekly_deaths       1434
# biweekly_cases      3284
# biweekly_deaths     3158
# year                   0
# month                  0
# day                    0
# dtype: int64

# %%
cov_death['total_deaths'] =cov_death ['total_deaths'].fillna(0)

# %%
cov_death.isnull().sum()
# Out:
# date                   0
# location               0
# new_cases            249
# new_deaths           204
# total_cases        28652
# total_deaths           0
# weekly_cases        1508
# weekly_deaths       1434
# biweekly_cases      3284
# biweekly_deaths     3158
# year                   0
# month                  0
# day                    0
# dtype: int64

# %%
cov_death=cov_death.dropna()
cov_death
# Out:
#              date     location  new_cases  new_deaths  total_cases  \
# 54     2020-02-26  Afghanistan        1.0         0.0          1.0
# 55     2020-02-27  Afghanistan        0.0         0.0          1.0
# 56     2020-02-28  Afghanistan        0.0         0.0          1.0
# 57     2020-02-29  Afghanistan        0.0         0.0          1.0
# 58     2020-03-01  Afghanistan        0.0         0.0          1.0
# ...           ...          ...        ...         ...          ...
# 344395 2023-10-29     Zimbabwe        0.0         0.0     265821.0
# 344396 2023-10-30     Zimbabwe        0.0         0.0     265821.0
# 344397 2023-10-31     Zimbabwe        0.0         0.0     265821.0
# 344398 2023-11-01     Zimbabwe        0.0         0.0     265821.0
# 344399 2023-11-02     Zimbabwe        0.0         0.0     265821.0
#
#         total_deaths  weekly_cases  weekly_deaths  biweekly_cases  \
# 54               0.0           1.0            0.0             1.0
# 55               0.0           1.0            0.0             1.0
# 56               0.0           1.0            0.0             1.0
# 57               0.0           1.0            0.0             1.0
# 58               0.0           1.0            0.0             1.0
# ...              ...           ...            ...             ...
# 344395        5720.0           0.0            0.0            13.0
# 344396        5720.0           0.0            0.0            13.0
# 344397        5720.0           0.0            0.0             0.0
# 344398        5720.0           0.0            0.0             0.0
# 344399        5720.0           0.0            0.0             0.0
#
#         biweekly_deaths  year  month  day
# 54                  0.0  2020      2   26
# 55                  0.0  2020      2   27
# 56                  0.0  2020      2   28
# 57                  0.0  2020      2   29
# 58                  0.0  2020      3    1
# ...                 ...   ...    ...  ...
# 344395              1.0  2023     10   29
# 344396              1.0  2023     10   30
# 344397              0.0  2023     10   31
# 344398              0.0  2023     11    1
# 344399              0.0  2023     11    2
#
# [315282 rows x 13 columns]

# %% [markdown]
# cov_death.duplicated().sum()

# %%
cov_death.shape
# Out:
# (315282, 13)

# %%
cov_death.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 315282 entries, 54 to 344399
# Data columns (total 13 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   date             315282 non-null  datetime64[ns]
#  1   location         315282 non-null  object
#  2   new_cases        315282 non-null  float64
#  3   new_deaths       315282 non-null  float64
#  4   total_cases      315282 non-null  float64
#  5   total_deaths     315282 non-null  float64
#  6   weekly_cases     315282 non-null  float64
#  7   weekly_deaths    315282 non-null  float64
#  8   biweekly_cases   315282 non-null  float64
#  9   biweekly_deaths  315282 non-null  float64
#  10  year             315282 non-null  int32
#  11  month            315282 non-null  int32
#  12  day              315282 non-null  int32
# dtypes: datetime64[ns](1), float64(8), int32(3), object(1)
# memory usage: 30.1+ MB

# %%
cov_death.describe()
# Out:
#                                 date     new_cases     new_deaths  \
# count                         315282  3.152820e+05  315282.000000
# mean   2022-01-13 08:34:47.913677312  1.037189e+04      92.383289
# min              2020-01-15 00:00:00  0.000000e+00       0.000000
# 25%              2021-02-15 00:00:00  0.000000e+00       0.000000
# 50%              2022-01-20 00:00:00  6.000000e+00       0.000000
# 75%              2022-12-14 00:00:00  3.600000e+02       4.000000
# max              2023-11-02 00:00:00  8.401960e+06   27939.000000
# std                              NaN  1.145604e+05     637.251869
#
#         total_cases  total_deaths  weekly_cases  weekly_deaths  \
# count  3.152820e+05  3.152820e+05  3.152820e+05  315282.000000
# mean   6.713567e+06  8.003899e+04  7.260325e+04     646.727124
# min    1.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 25%    8.250000e+03  8.000000e+01  1.000000e+01       0.000000
# 50%    7.104800e+04  9.210000e+02  2.690000e+02       2.000000
# 75%    7.530562e+05  9.756000e+03  4.318000e+03      45.000000
# max    7.716789e+08  6.977010e+06  4.481426e+07  103754.000000
# std    4.103396e+07  4.265293e+05  6.856977e+05    4056.481235
#
#        biweekly_cases  biweekly_deaths           year          month  \
# count    3.152820e+05    315282.000000  315282.000000  315282.000000
# mean     1.452005e+05      1293.374243    2021.534401       6.536025
# min      0.000000e+00         0.000000    2020.000000       1.000000
# 25%      2.700000e+01         0.000000    2021.000000       4.000000
# 50%      5.620000e+02         4.000000    2022.000000       7.000000
# 75%      8.731000e+03        92.000000    2022.000000       9.000000
# max      7.335243e+07    205483.000000    2023.000000      12.000000
# std      1.321841e+06      8094.260877       1.074216       3.280035
#
#                  day
# count  315282.000000
# mean       15.772788
# min         1.000000
# 25%         8.000000
# 50%        16.000000
# 75%        23.000000
# max        31.000000
# std         8.813384

# %%
cov_loc=cov_death.groupby('location')[['total_cases','total_deaths']].sum().sort_values('total_cases',ascending=False)
cov_loc
# Out:
#                       total_cases  total_deaths
# location
# World                5.038218e+11  6.087139e+09
# High income          2.761736e+11  2.486902e+09
# Asia                 1.699112e+11  1.344703e+09
# Europe               1.675412e+11  1.786178e+09
# Upper middle income  1.448287e+11  2.361995e+09
# ...                           ...           ...
# Montserrat           7.461310e+05  5.059000e+03
# Niue                 2.631800e+05  0.000000e+00
# Vatican              3.125800e+04  0.000000e+00
# Tokelau              1.046800e+04  0.000000e+00
# Pitcairn             1.884000e+03  0.000000e+00
#
# [244 rows x 2 columns]

# %%
cov_loc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 244 entries, World to Pitcairn
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   total_cases   244 non-null    float64
#  1   total_deaths  244 non-null    float64
# dtypes: float64(2)
# memory usage: 5.7+ KB

# %%
cov_loc['taux_MRT']=cov_loc['total_deaths']/cov_loc['total_cases']
cov_loc
# Out:
#                       total_cases  total_deaths  taux_MRT
# location
# World                5.038218e+11  6.087139e+09  0.012082
# High income          2.761736e+11  2.486902e+09  0.009005
# Asia                 1.699112e+11  1.344703e+09  0.007914
# Europe               1.675412e+11  1.786178e+09  0.010661
# Upper middle income  1.448287e+11  2.361995e+09  0.016309
# ...                           ...           ...       ...
# Montserrat           7.461310e+05  5.059000e+03  0.006780
# Niue                 2.631800e+05  0.000000e+00  0.000000
# Vatican              3.125800e+04  0.000000e+00  0.000000
# Tokelau              1.046800e+04  0.000000e+00  0.000000
# Pitcairn             1.884000e+03  0.000000e+00  0.000000
#
# [244 rows x 3 columns]

# %%
plt.figure(figsize=(10,10))
sorted_death=cov_loc.sort_values(by='taux_MRT',ascending=False).head(20)
ax = sorted_death['taux_MRT'].plot(kind='bar')
ax.set_xticklabels(sorted_death.index,rotation=45,ha="right")
ax.set_xlabel('Pays')
ax.set_ylabel('les taux de mortalité')
ax.set_title('pays avec les taux de mortalite les plus élevés')
plt.show()

# %%
#SORTING THE NUMBER OF DEATHS IN THE DESCEDING ORDER
plt.figure(figsize=(10,10))
ax=cov_loc['total_deaths'].sort_values(ascending=False).head(10).plot(kind='bar')
ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
ax.set_title("countries suffering the most fatalities from COVId-19")
ax.set_xlabel("countries")
ax.set_ylabel('number fo deaths')
# Out:
# Text(0, 0.5, 'number fo deaths')

# %%
# Créer un graphique linéaire
plt.plot(cov_death['day'], cov_death['new_cases'])
plt.xlabel('Jours')
plt.ylabel('Nouveaux cas confirmés par jour')
plt.title('Évolution des cas quotidiens de COVID-19')
plt.show()

# %%
df_by_month = cov_death.groupby('month')[['new_cases','new_deaths']].sum()

# %%
fig=plt.figure(figsize=(15,10))
ax1=fig.add_subplot(1,2,1)
ax2=fig.add_subplot(1,2,2)

df_by_month['new_cases'].plot(kind='line',ax=ax1)
ax1.set_title("Nombre total de cas de covid par mois")
ax1.set_xlabel("Mois")
ax1.set_ylabel("Nombre de cas annee 2020")
df_by_month['new_deaths'].plot(kind='line',ax=ax2)
ax2.set_title("Nombre total de morts par mois")
ax2.set_xlabel("Mois")
ax2.set_ylabel("Nombre de morts annee 2020")
# Out:
# Text(0, 0.5, 'Nombre de morts annee 2020')

# %%
years=cov_death['year'].unique()

# %%
of_year=cov_death.groupby('year')['total_deaths'].sum()
of_year
# Out:
# year
# 2020    1.003128e+09
# 2021    5.962028e+09
# 2022    9.611565e+09
# 2023    8.658132e+09
# Name: total_deaths, dtype: float64

# %%
plt.bar(years,of_year,color='black',label=('nombr death '))
plt.xlabel('year')
plt.ylabel('deaths')
plt.title('nombr death of the year ')
plt.legend()
plt.show()

# %%
plt.pie(of_year,autopct='%2.2f%%',labels=years)
plt.legend()
plt.show()
